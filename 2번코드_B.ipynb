# %%
from scipy.optimize import curve_fit
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import warnings
import ruptures as rpt
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_absolute_error as MAE
plt.style.use('ggplot')
warnings.filterwarnings("ignore")

# %%
def f(X, K, T):
    x, t = X    
    return K * (1 - np.exp(-t / T)) * x

# %%
def make_data(x, y, x_cp_list, y_cp_list, D):
    data = []
    for cp in x_cp_list[:-1]:
        LR_y = x[cp-1:cp+2]
        LR_x = np.array(range(1, len(LR_y) + 1)).reshape(-1, 1)

        old_theta = LR().fit(LR_x, LR_y).coef_[0]
        a = 2
        while True:
            LR_y = x[cp-a:cp+a+1]
            LR_x = np.array(range(1, len(LR_y) + 1)).reshape(-1, 1)
            new_theta = LR().fit(LR_x, LR_y).coef_[0]

            if (new_theta * old_theta < 0) or (abs(new_theta) - abs(old_theta)) / abs(old_theta) > eps or (a >= cp):
                a -= 1
                break    
            a += 1
            old_theta = new_theta    

        t = 1
        for x_val, y_val in zip(x[cp-a:cp+a+1], y[cp-a+D:cp+a+1+D]):
            try:
                record = [t, x_val, y_val]
                data.append(record)
            except:
                pass
            t+=1
            
    for cp in y_cp_list[:-1]:
        LR_y = y[cp-1:cp+2]
        LR_x = np.array(range(1, len(LR_y) + 1)).reshape(-1, 1)

        old_theta = LR().fit(LR_x, LR_y).coef_[0]
        a = 2
        while True:
            LR_y = x[cp-a:cp+a+1]
            LR_x = np.array(range(1, len(LR_y) + 1)).reshape(-1, 1)
            new_theta = LR().fit(LR_x, LR_y).coef_[0]

            if (new_theta * old_theta < 0) or (abs(new_theta) - abs(old_theta)) / abs(old_theta) > eps or (a >= cp):
                a -= 1
                break    
            a += 1
            old_theta = new_theta    
        
        t = 1
        for x_val, y_val in zip(x[cp-a-D:cp+a+1-D], y[cp-a:cp+a+1]):
            try:
                record = [t, x_val, y_val]
                data.append(record)        
            except:
                pass
            t += 1
        
    data = pd.DataFrame(data, columns = ["t", "x", "y"])
    return data

# %%
def evaluate(train_data, test_data):
    X = train_data[['x', 't']].T.values
    y = train_data['y'].values    
    
    X_test = test_data[['x', 't']].T.values
    y_test = test_data['y'].values
    
    K_hat, T_hat = curve_fit(f, X, y)[0]    
    y_hat = f(X_test, K_hat, T_hat)
    
    return MAE(y_test, y_hat)

# %%
s_train_df = pd.read_excel("Plant S_Data추가.xlsx", sheet_name = "Temp_Data04").iloc[:1440*5]
s_test_df = pd.read_excel("Plant S_Data추가.xlsx", sheet_name = "Temp_Data03").iloc[:1440*5]

# %%
result = []
num_iter = 0
for train_df, test_df, idx in zip([s_train_df], [s_test_df], ["s"]):
    for var in ["DV", "MV"]:
        for algorithm in [rpt.Pelt, rpt.KernelCPD]:
            for D in [0, 3, 5, 10]:
                for ms in [5, 10, 15, 20]:
                    for eps in [0.01, 0.05, 0.1]:
                        for pen in [3]:
                            for kernel in ["linear", "rbf", "cosine"]:                        
                                x_train = train_df[var].values
                                y_train = train_df['CV'].values

                                x_test = test_df[var].values
                                y_test = test_df['CV'].values

                                if algorithm.__name__ == "Pelt":
                                    x_train_cp_list = algorithm(min_size = ms).fit(x_train).predict(pen = pen)
                                    y_train_cp_list = algorithm(min_size = ms).fit(y_train).predict(pen = pen)
                                    x_test_cp_list = algorithm(min_size = ms).fit(x_test).predict(pen = pen)
                                    y_test_cp_list = algorithm(min_size = ms).fit(y_test).predict(pen = pen)
                                    try:
                                        train_data = make_data(x_train, y_train, x_train_cp_list, y_train_cp_list, D)
                                        test_data = make_data(x_test, y_test, x_test_cp_list, y_test_cp_list, D)
                                        score = evaluate(train_data, test_data)
                                        record = [idx, var, algorithm.__name__, kernel, D, ms, eps, len(x_train_cp_list), len(x_test_cp_list), len(y_train_cp_list), len(y_test_cp_list), score]   
                                        result.append(record)
                                    except:
                                        pass
                                    num_iter += 1
                                    print(num_iter, "/1536")

                                    break

                                else:
                                    x_train_cp_list = algorithm(min_size = ms, kernel = kernel).fit(x_train).predict(pen = pen)
                                    y_train_cp_list = algorithm(min_size = ms, kernel = kernel).fit(y_train).predict(pen = pen)
                                    x_test_cp_list = algorithm(min_size = ms, kernel = kernel).fit(x_test).predict(pen = pen)
                                    y_test_cp_list = algorithm(min_size = ms, kernel = kernel).fit(y_test).predict(pen = pen)
                                    
                                    try:
                                        train_data = make_data(x_train, y_train, x_train_cp_list, y_train_cp_list, D)
                                        test_data = make_data(x_test, y_test, x_test_cp_list, y_test_cp_list, D)
                                        score = evaluate(train_data, test_data)
                                        record = [idx, var, algorithm.__name__, kernel, D, ms, eps, len(x_train_cp_list), len(x_test_cp_list), len(y_train_cp_list), len(y_test_cp_list), score]   
                                        result.append(record)
                                    except:
                                        pass        
                                    
                                    num_iter += 1                                    
                                    print(num_iter, "/1536")
# Out:
# 1 /1536
# 2 /1536
# 3 /1536
# 4 /1536
# 5 /1536
# 6 /1536
# 7 /1536
# 8 /1536
# 9 /1536
# 10 /1536
# 11 /1536
# 12 /1536
# 13 /1536
# 14 /1536
# 15 /1536
# 16 /1536
# 17 /1536
# 18 /1536
# 19 /1536
# 20 /1536
# 21 /1536
# 22 /1536
# 23 /1536
# 24 /1536
# 25 /1536
# 26 /1536
# 27 /1536
# 28 /1536
# 29 /1536
# 30 /1536
# 31 /1536
# 32 /1536
# 33 /1536
# 34 /1536
# 35 /1536
# 36 /1536
# 37 /1536
# 38 /1536
# 39 /1536
# 40 /1536
# 41 /1536
# 42 /1536
# 43 /1536
# 44 /1536
# 45 /1536
# 46 /1536
# 47 /1536
# 48 /1536
# 49 /1536
# 50 /1536
# 51 /1536
# 52 /1536
# 53 /1536
# 54 /1536
# 55 /1536
# 56 /1536
# 57 /1536
# 58 /1536
# 59 /1536
# 60 /1536
# 61 /1536
# 62 /1536
# 63 /1536
# 64 /1536
# 65 /1536
# 66 /1536
# 67 /1536
# 68 /1536
# 69 /1536
# 70 /1536
# 71 /1536
# 72 /1536
# 73 /1536
# 74 /1536
# 75 /1536
# 76 /1536
# 77 /1536
# 78 /1536
# 79 /1536
# 80 /1536
# 81 /1536
# 82 /1536
# 83 /1536
# 84 /1536
# 85 /1536
# 86 /1536
# 87 /1536
# 88 /1536
# 89 /1536
# 90 /1536
# 91 /1536
# 92 /1536
# 93 /1536
# 94 /1536
# 95 /1536
# 96 /1536
# 97 /1536
# 1418 /1536
# 1419 /1536
# 1420 /1536
# 1421 /1536
# 1422 /1536
# 1423 /1536
# 1424 /1536
# 1425 /1536
# 1426 /1536
# 1427 /1536
# 1428 /1536
# 1429 /1536
# 1430 /1536
# 1431 /1536
# 1432 /1536
# 1433 /1536
# 1434 /1536
# 1435 /1536
# 1436 /1536
# 1437 /1536
# 1438 /1536
# 1439 /1536
# 1440 /1536
# 1441 /1536
# 1442 /1536
# 1443 /1536
# 1444 /1536
# 1445 /1536
# 1446 /1536
# 1447 /1536
# 1448 /1536
# 1449 /1536
# 1450 /1536
# 1451 /1536
# 1452 /1536
# 1453 /1536
# 1454 /1536
# 1455 /1536
# 1456 /1536
# 1457 /1536
# 1458 /1536
# 1459 /1536
# 1460 /1536
# 1461 /1536
# 1462 /1536
# 1463 /1536
# 1464 /1536
# 1465 /1536
# 1466 /1536
# 1467 /1536
# 1468 /1536
# 1469 /1536
# 1470 /1536
# 1471 /1536
# 1472 /1536
# 1473 /1536
# 1474 /1536
# 1475 /1536
# 1476 /1536
# 1477 /1536
# 1478 /1536
# 1479 /1536
# 1480 /1536
# 1481 /1536
# 1482 /1536
# 1483 /1536
# 1484 /1536
# 1485 /1536
# 1486 /1536
# 1487 /1536
# 1488 /1536
# 1489 /1536
# 1490 /1536
# 1491 /1536
# 1492 /1536
# 1493 /1536
# 1494 /1536
# 1495 /1536
# 1496 /1536
# 1497 /1536
# 1498 /1536
# 1499 /1536
# 1500 /1536
# 1501 /1536
# 1502 /1536
# 1503 /1536
# 1504 /1536
# 1505 /1536
# 1506 /1536
# 1507 /1536
# 1508 /1536
# 1509 /1536
# 1510 /1536
# 1511 /1536
# 1512 /1536
# 1513 /1536
# 1514 /1536
# 1515 /1536
# 1516 /1536
# 1517 /1536
# 1518 /1536
# 1519 /1536
# 1520 /1536
# 1521 /1536
# 1522 /1536
# 1523 /1536
# 1524 /1536
# 1525 /1536
# 1526 /1536
# 1527 /1536
# 1528 /1536
# 1529 /1536
# 1530 /1536
# 1531 /1536
# 1532 /1536
# 1533 /1536
# 1534 /1536
# 1535 /1536
# 1536 /1536

# %%
result = pd.DataFrame(result, columns = ["data", "x_var", "algorithm", "kernel", "D", "ms", "eps", "x_train_cp_길이", "x_test_cp_길이", "y_train_cp_길이", "y_test_cp_길이", "score"])

# %%
result = result.drop_duplicates(subset = ['x_var', 'algorithm', 'kernel', 'D', 'ms', 'eps'])

# %%
result.to_csv("유요셉_실험결과_s.csv", encoding = "euc-kr")

# %%
mv_result = result.loc[result['x_var'] == 'MV']
dv_result = result.loc[result['x_var'] == 'DV']

# %%
display(mv_result.sort_values(by = 'score').iloc[:10])
display(dv_result.sort_values(by = 'score').iloc[:10])
# Out:
#      data x_var  algorithm  kernel   D  ms   eps  x_train_cp_길이  x_test_cp_길이  \
# 793     s    MV  KernelCPD     rbf   0  10  0.01             33            19
# 769     s    MV  KernelCPD     rbf   0   5  0.01             35            19
# 841     s    MV  KernelCPD     rbf   0  20  0.01             32            19
# 784     s    MV  KernelCPD  linear   0   5  0.10            473            35
# 776     s    MV  KernelCPD  linear   0   5  0.05            473            35
# 817     s    MV  KernelCPD     rbf   0  15  0.01             32            19
# 785     s    MV  KernelCPD     rbf   0   5  0.10             35            19
# 1081    s    MV  KernelCPD     rbf  10  10  0.01             33            19
# 985     s    MV  KernelCPD     rbf   5  10  0.01             33            19
# 833     s    MV  KernelCPD     rbf   0  15  0.10             32            19
#
#       y_train_cp_길이  y_test_cp_길이      score
# 793              66            76  45.264157
# 769              81            80  45.520872
# 841              55            72  45.775182
# 784             195           206  45.834073
# 776             195           206  45.849358
# 817              60            73  45.896156
# 785              81            80  45.936669
# 1081             66            76  46.000965
# 985              66            76  46.033829
# 833              60            73  46.043436
#     data x_var  algorithm  kernel   D  ms   eps  x_train_cp_길이  x_test_cp_길이  \
# 361    s    DV  KernelCPD     rbf   3  20  0.01            114            76
# 457    s    DV  KernelCPD     rbf   5  20  0.01            114            76
# 265    s    DV  KernelCPD     rbf   0  20  0.01            114            76
# 553    s    DV  KernelCPD     rbf  10  20  0.01            114            76
# 44     s    DV       Pelt  linear   0  20  0.10             87           109
# 216    s    DV  KernelCPD  linear   0  10  0.01            100           127
# 312    s    DV  KernelCPD  linear   3  10  0.01            100           127
# 92     s    DV       Pelt  linear   3  20  0.10             87           109
# 408    s    DV  KernelCPD  linear   5  10  0.01            100           127
# 140    s    DV       Pelt  linear   5  20  0.10             87           109
#
#      y_train_cp_길이  y_test_cp_길이     score
# 361             55            72  3.987124
# 457             55            72  3.988567
# 265             55            72  3.990004
# 553             55            72  3.994029
# 44             108           150  4.094297
# 216            163           188  4.148142
# 312            163           188  4.149616
# 92             108           150  4.150099
# 408            163           188  4.153172
# 140            108           150  4.154886

# %%
mv_result.groupby(['algorithm', 'kernel'])['score'].mean().reset_index()
# Out:
#    algorithm  kernel      score
# 0  KernelCPD  linear  47.525187
# 1  KernelCPD     rbf  46.326916
# 2       Pelt  linear  49.346287

# %%
dv_result.groupby(['algorithm', 'kernel'])['score'].mean().reset_index()
# Out:
#    algorithm  kernel     score
# 0  KernelCPD  linear  4.293719
# 1  KernelCPD     rbf  4.341620
# 2       Pelt  linear  4.400131

# %%
mv_result.groupby(['D'])['score'].mean().reset_index()
# Out:
#     D      score
# 0   0  47.305815
# 1   3  47.877064
# 2   5  47.883309
# 3  10  47.864999

# %%
dv_result.groupby(['D'])['score'].mean().reset_index()
# Out:
#     D     score
# 0   0  4.327684
# 1   3  4.345038
# 2   5  4.348035
# 3  10  4.359868

# %%
mv_result.groupby(['ms'])['score'].mean().reset_index()
# Out:
#    ms      score
# 0   5  47.221883
# 1  10  47.544368
# 2  15  48.032792
# 3  20  48.132144

# %%
dv_result.groupby(['ms'])['score'].mean().reset_index()
# Out:
#    ms     score
# 0   5  4.371485
# 1  10  4.324087
# 2  15  4.386966
# 3  20  4.298089

# %%
mv_result.groupby(['eps'])['score'].mean().reset_index()
# Out:
#     eps      score
# 0  0.01  48.184318
# 1  0.05  47.632912
# 2  0.10  47.381161

# %%
dv_result.groupby(['eps'])['score'].mean().reset_index()
# Out:
#     eps     score
# 0  0.01  4.270740
# 1  0.05  4.337487
# 2  0.10  4.427242
